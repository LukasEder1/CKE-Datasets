# %% [markdown]
# <a href="https://colab.research.google.com/github/LukasEder1/CKE-Datasets/blob/main/Demo/InspectDatasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone "https://github.com/LukasEder1/CKE-Datasets.git"
# Out:
# Cloning into 'CKE-Datasets'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 21 (delta 9), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (21/21), 818.33 KiB | 1.29 MiB/s, done.

# %%
import pandas as pd

# %%
policies = pd.read_csv("/content/CKE-Datasets/policies.csv")
articles = pd.read_csv("/content/CKE-Datasets/articles.csv")

# %% [markdown]
# # Princeton-Leuven Longitudinal Corpus of Privacy Policies

# %%
policies.head(10)
# Out:
#        Id                                           Keywords  \
# 0   90536  ['European Union', 'cookies', 'bugs', 'persona...
# 1   90344  ['Telerik', 'May', 'Progress Software', 'softw...
# 2   98640  ['validation page', 'scripts', 'removing HTML5...
# 3   98585  ['account settings', 'center cloud', 'cloud co...
# 4   99880  ['reproductive science', 'science center', 'Mi...
# 5  108079  ['destination nsw', 'Insights', 'Viva Sydney',...
# 6   90555  ['serve ads', 'DART cookie', 'registration num...
# 7   90545  ['Yahoo privacy', 'Privacy Policy', 'AOL', 'Oa...
# 8   98553  ['customeraffiliated websites', 'providers', '...
# 9   98572  ['job applications', 'Privacy Shield', 'Shield...
#
#                                                TextA  \
# 0  ## This Privacy Policy is effective as of Sept...
# 1  Last update: Tuesday, November 15, 2011\n\nWe ...
# 2  Effective Date: 08/07/2014  \nPosting Date: 08...
# 3  ## Kaspersky Lab Privacy Policy for Websites\n...
# ...

# %%
policies.iloc[0].Keywords
# Out:
# "['European Union', 'cookies', 'bugs', 'personally identifiable', 'Salesforce', 'identifiable information', 'customer testimonial', 'version', 'Third Party', 'clear gifs', 'web beacons', 'service providers', 'blog']"

# %% [markdown]
# # News Edits: News Article Revision

# %%
articles.head(10)
# Out:
#       Id                                           Keywords  \
# 0  16532  ['Toys R', 'R us', 'toy makers', 'Hong Kong', ...
# 1   7335  ['nuclear weapons', 'united states', 'north ko...
# 2  16625  ['50 million', 'million users', 'trump campaig...
# 3   3694  ['filmmaker Jason', 'Jason Pollock', 'departme...
# 4   7409  ['Puerto ricans', 'statehood', 'lost loved', '...
# 5   1525  ['white house', 'TRUMP ADMINISTRATION', 'pales...
# 6  16699  ['prime minister', 'foreign leaders', 'bilater...
# 7   8370  ['removed 92', '92 million', 'million videos',...
# 8  15397  ['31, 2018', 'united states', 'Quarterly progr...
# 9  17354  ['Researcher Autumn', 'Autumn Stroup', 'city r...
#
#                                                TextA  \
# 0   NEW YORK (AP) -- Toys R Us is headed toward s...
# 1   SEOUL, South Korea (AP) -- South Korean media...
# 2  Facebook suspended Cambridge Analytica, a data...
# 3   CLAYTON, Mo.\n(AP) -- St. Louis County prosec...
# ...

# %%
articles.iloc[1].Keywords
# Out:
# "['nuclear weapons', 'united states', 'north korea', 'Yoon said', 'Park Geun-hye', 'missile provocation', 'last week', 'Hwasong-12 missile']"
